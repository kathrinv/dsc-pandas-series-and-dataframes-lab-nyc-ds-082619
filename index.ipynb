# %% [markdown]
# # Understanding Pandas Series and DataFrames - Lab
#
# ## Introduction
#
# In this lab, let's get some hands on practice working with data cleanup using Pandas.
#
# ## Objectives
# You will be able to:
#
# * Manipulate columns in DataFrames (df.rename, df.drop)
# * Manipulate the index in DataFrames (df.reindex, df.drop, df.rename)
# * Manipulate column datatypes
#
# ## Let's get started!

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('turnstile_180901.txt')
print(len(df))
df.head()
# Out:
# 197625
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    EXITS
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Rename all the columns to lower case

# %%
#Your code here
# Using .columns attribute
df.columns = list(map(lambda x: x.lower(), df.columns))

# %%
df.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
# Using a dictionary
col_dict = {}
for col in df.columns: 
    col_dict[col] = col.lower()
dfnew = df.rename(columns=col_dict)

# %%
dfnew.head()
# Out:
#     c/a  unit       scp station linename division        date      time  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %%
list(map(lambda x: x.lower(), df.columns))
# Out:
# ['c/a',
#  'unit',
#  'scp',
#  'station',
#  'linename',
#  'division',
#  'date',
#  'time',
#  'desc',
#  'entries',
#  'exits                                                               ']

# %% [markdown]
# ## Change the Index to be the Line Names

# %%
df = df.set_index('linename')
df.head()
# Out:
#            c/a  unit       scp station division        date      time  \
# linename
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# NQR456W   A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#              desc  entries  \
# linename
# NQR456W   REGULAR  6736067
# NQR456W   REGULAR  6736087
# NQR456W   REGULAR  6736105
# NQR456W   REGULAR  6736180
# NQR456W   REGULAR  6736349
#
#           exits
# linename
# NQR456W                                             2283184
# NQR456W                                             2283188
# NQR456W                                             2283229
# NQR456W                                             2283314
# NQR456W                                             2283384

# %% [markdown]
# ## Change the index back

# %%
df = df.reset_index()
df.head()
# Out:
#   linename   c/a  unit       scp station division        date      time  \
# 0  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  00:00:00
# 1  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  04:00:00
# 2  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  08:00:00
# 3  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  12:00:00
# 4  NQR456W  A002  R051  02-00-00   59 ST      BMT  08/25/2018  16:00:00
#
#       desc  entries  \
# 0  REGULAR  6736067
# 1  REGULAR  6736087
# 2  REGULAR  6736105
# 3  REGULAR  6736180
# 4  REGULAR  6736349
#
#    exits
# 0                                            2283184
# 1                                            2283188
# 2                                            2283229
# 3                                            2283314
# 4                                            2283384

# %% [markdown]
# ## Create another column 'Num_Lines' that is a count of how many lines pass through a station. Then sort your dataframe by this column in descending order
# *Hint: According to the [data dictionary](http://web.mta.info/developers/resources/nyct/turnstile/ts_Field_Description.txt), LINENAME represents all train lines that can be boarded at a given station. Normally lines are represented by one character. For example, LINENAME 456NQR represents trains 4, 5, 6, N, Q, and R.*

# %%
df['num_lines'] = df['linename'].map(lambda x: len(x))

# %%
df.sample(10)
# Out:
#        linename   c/a  unit       scp          station division        date  \
# 156434        6  R248  R178  00-00-05            77 ST      IRT  08/25/2018
# 11217      FJMZ  A061  R142  00-03-01   DELANCEY/ESSEX      BMT  08/25/2018
# 195551        5  R728  R226  00-00-01      GUN HILL RD      IRT  08/29/2018
# 67633        AS  N185  R417  00-00-00      BEACH 98 ST      IND  08/26/2018
# 46428        BC  N045  R187  01-06-01     81 ST-MUSEUM      IND  08/27/2018
# 69821       BD4  N203  R195  00-00-01  161/YANKEE STAD      IND  08/30/2018
# 46178        BC  N044  R187  00-03-01     81 ST-MUSEUM      IND  08/28/2018
# 193638       25  R639  R109  00-05-00        CHURCH AV      IRT  08/25/2018
# 78331        MR  N317  R267  02-06-00            46 ST      IND  08/25/2018
# 12004     JZ456  A071  R044  02-00-02      CHAMBERS ST      BMT  08/30/2018
#
#             time     desc     entries  \
# 156434  13:00:00  REGULAR    14458285
# 11217   09:00:00  REGULAR     3253081
# ...

# %% [markdown]
# ## Write a function to clean a column name

# %%
df.desc.value_counts()
# Out:
# REGULAR       196675
# RECOVR AUD       950
# Name: desc, dtype: int64

# %%
def clean(col_name):
    cleaned = col_name.replace('/', '-')
    cleaned = cleaned.replace('_', '-')
    return cleaned

# %%
# This is a list comprehension. It applies your clean function to every item in the list.
# We then reassign that to df.columns
# You shouldn't have to change anything here.
# Your function above should work appropriately here.
df.columns = [clean(col) for col in df.columns]

# %%
# Checking the output, we can see the results.
df.columns
# Out:
# Index(['linename', 'c-a', 'unit', 'scp', 'station', 'division', 'date', 'time',
#        'desc', 'entries',
#        'exits                                                               ',
#        'num-lines'],
#       dtype='object')

# %% [markdown]
# ## Group the Data by Day of Week and Plot the Sum of The Numeric Columns

# %%
# df[]
sum_by_date = df.groupby('date').sum()

# %%
sum_by_date.plot(kind='bar')

# %% [markdown]
# ## Group the Data by Weekend/Weekday and Plot the Sum of the Numeric Columns

# %%
#Your code here
df['weekend-weekday'] = df['date'].map(lambda x: 'weekend' if ((x == '08/25/2018') or (x == '08/26/2018')) else 'weekday')

# %%
sum_by_day_of_week = df.groupby('weekend-weekday').sum()
sum_by_day_of_week.plot(kind='bar')

# %% [markdown]
# ## Analysis Question:
#
# What is misleading about the day of week and weekend/weekday charts you just plotted?

# %%
# Your answer here 
# There are 5 days worth of entries and exits for the weekday bar, but only 2 days for the weekend bar.
# Also, you can't see the num-lines because the value is too small compared to the entries and exits

# %% [markdown]
# ## Drop a couple of columns

# %%
df.sample()
# Out:
#        linename   c-a  unit       scp   station division        date  \
# 103171        F  N553  R422  00-00-01  BAY PKWY      IND  08/26/2018
#
#             time     desc  entries  \
# 103171  09:00:00  REGULAR  2276573
#
#         exits                                                                 \
# 103171                                             862354
#
#         num-lines weekend-weekday
# 103171          1         weekend

# %%
# Your code here
df_new = df.drop(columns='num-lines')
df_new.sample()
# Out:
#        linename   c-a  unit       scp      station division        date  \
# 122797      1RW  R101  R001  02-00-05  SOUTH FERRY      IRT  08/26/2018
#
#             time     desc  entries  \
# 122797  09:00:00  REGULAR  2676199
#
#         exits                                                                 \
# 122797                                            1833460
#
#        weekend-weekday
# 122797         weekend

# %%
grouped_df = df_new.groupby('weekend-weekday').sum()
# print(grouped_df / grouped_df['weekend-weekday'].map(lambda x: 2 if x == 'weekend' else 5))

# %% [markdown]
# ## Summary
#
# Great! You practiced your data cleanup-skills using Pandas.
